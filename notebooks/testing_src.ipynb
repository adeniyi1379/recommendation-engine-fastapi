# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
from src.data_loader import load_data

# %%
rating , movies= load_data("../data/")

# %%
rating.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
from src.matrix_factorization import train_svd_model
model, testset  = train_svd_model(rating)

# %%
from src.evaluation import evaluate_model
evaluate_model(model, testset)
# Out:
# 0.8808746709977849

# %%
from src.recommender import get_top_n_recommendations

# %%
top_movies = get_top_n_recommendations(user_id=5, model=model, ratings=rating,movies=movies, n=5)
top_movies
# Out:
#    movieId  predicted_rating  \
# 0     2959          4.314013
# 1     1945          4.304767
# 2      750          4.301058
# 3    58559          4.299069
# 4     2028          4.289020
#
#                                                title  \
# 0                                  Fight Club (1999)
# 1                           On the Waterfront (1954)
# 2  Dr. Strangelove or: How I Learned to Stop Worr...
# 3                            Dark Knight, The (2008)
# 4                         Saving Private Ryan (1998)
#
#                         genres
# 0  Action|Crime|Drama|Thriller
# 1                  Crime|Drama
# 2                   Comedy|War
# 3      Action|Crime|Drama|IMAX
# 4             Action|Drama|War

# %%
import pickle

# %%
from src.model_utils import save_model, load_model

# %%
save_model(model, "../models/svd_model.pkl")

# %%
model_load = load_model("../models/svd_model.pkl")

# %%
ppred= model_load.predict(1,50)

# %%
ppred.est
# Out:
# 4.786346268347597
